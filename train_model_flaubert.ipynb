# %%
import torch

from transformers import FlaubertForSequenceClassification, FlaubertTokenizer

from src.dataset import FactsOrAnalysisDS_BERT
from src.models import FoaFlauBERTlinear
from src.train import trainIters

device = torch.device("cpu")
flaubert_seq = FlaubertForSequenceClassification.from_pretrained('flaubert-base-uncased',num_labels=1)
tokeniser = FlaubertTokenizer.from_pretrained('flaubert-base-uncased')

# %%
ds = "data/dataset_sentences_facts_non_facts20200311.pickle"
ds = FactsOrAnalysisDS_BERT(ds,tokeniser,n_read=2048*2)
tr = int(len(ds)*.70)
vd = int(len(ds)*.10)
ts = len(ds) - tr - vd
train_ds, valid_ds, test_ds = torch.utils.data.random_split(ds,[tr,vd,ts])

# %%
model=FoaFlauBERTlinear(flaubert_seq).to(device)

## CONFIG
batch_size=16
n_epochs=5
learning_rate=1e-4
weight_decay=0
clip=.2
## /CONFIG

t,v=trainIters(model,
               train_ds,
               valid_ds,
               batch_size,
               n_epochs,
               learning_rate,
               weight_decay,
               clip,
               device)
# Out:
# CUDA is available!
# HBox(children=(IntProgress(value=0, description='Epoch', max=5, style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='Training', max=180, style=ProgressStyle(description_width='in…
# /home/andres/miniconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/andres/miniconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-13d98a335dca> in <module>
#      17                weight_decay,
#      18                clip,
# ---> 19                device)
#
# ~/JusticeBot/src/train.py in trainIters(model, train_dset, valid_dset, batch_size, n_epochs, learning_rate, weight_decay, clip, device, collate_fn)
#     110                                            criterion,
#     111                                            clip,
# --> 112                                            lengths)
#     113             accuracy,f1,precision,recall=test(target,prediction)
#     114             avg_train.append(train_loss)
#
# ~/JusticeBot/src/train.py in train(input_tensor, target, model, optimiser, criterion, clip, lengths)
#      20     loss = criterion(prediction.squeeze(1),target)
#      21     loss.backward()
# ---> 22     torch.nn.utils.clip_grad_norm_(model.parameters(),clip)
#      23     optimiser.step()
#      24     return loss.item(), prediction
#
# ~/miniconda3/lib/python3.7/site-packages/torch/nn/utils/clip_grad.py in clip_grad_norm_(parameters, max_norm, norm_type)
#      36     if clip_coef < 1:
#      37         for p in parameters:
# ---> 38             p.grad.data.mul_(clip_coef)
#      39     return total_norm
#      40
#
# KeyboardInterrupt:
